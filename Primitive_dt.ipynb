# %% [markdown]
# # Primitive Data Types

# %% [markdown]
# ### Integer: int

# %%
age = 20
print(age)
print(type(age))
# Out:
# 20
# <class 'int'>

# %% [markdown]
# ### Float: float

# %%
price = 99.50
print(price)
print(type(price))
# Out:
# 99.5
# <class 'float'>

# %% [markdown]
# ### Complex: complex

# %%
number = 2 + 3j
print(number)
# Out:
# (2+3j)

# %%
x =2+3j
print(x.imag)
print(type(x))
# Out:
# 3.0
# <class 'complex'>

# %%
z= 2 + 3j
print( z.real)
print(type(z))
# Out:
# 2.0
# <class 'complex'>

# %% [markdown]
# ### Boolean: bool

# %% [markdown]
# ### String: str

# %%
name = "Rahul"
print(name)
print(type(name))
# Out:
# Rahul
# <class 'str'>

# %% [markdown]
# ### NoneType
