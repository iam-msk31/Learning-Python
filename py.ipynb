# %%
print("Hello, World!")
# Out:
# Hello, World!

# %%
# Data type 

a = 28888
a2 = 777
print(a+a2)
b= "Quad AI"
print (b)

print("type of a is ",type(a))
# Out:
# 29665
# Quad AI
# type of a is  <class 'int'>

# %% [markdown]
# # --> NUMERIC DATA TYPE

# %%
#int (whole number)

a=35
print (a)
print (type(a))
# Out:
# 35
# <class 'int'>
# <class 'NoneType'>

# %%
# float (decimal number)

pi = 3.14
print(pi)
print(type(pi))
# Out:
# 3.14
# <class 'float'>

# %%
#complex number (real + imaginary)

b= 2+3j
j=6
print (b)
print(type(b))
# Out:
# (2+3j)
# <class 'complex'>

# %% [markdown]
# # --> STRING DATA TYPE

# %%
name="Mohammad Samar"
print(name)
print(type(name))
# Out:
# Mohammad Samar
# <class 'str'>

# %% [markdown]
# # --> BOOLEN DATA TYPE

# %%
a=True
b=False
print(type(a))
# Out:
# <class 'bool'>

# %% [markdown]
# # --> NONE TYPE

# %%
nothing = None
print(type(nothing))
# Out:
# <class 'NoneType'>

# %% [markdown]
# # --> RANGE DATA TYPE

# %%
r = range(2, 7)  
print ("range(2, 7):", list(r))
# Out:
# range(2, 7): [2, 3, 4, 5, 6]
